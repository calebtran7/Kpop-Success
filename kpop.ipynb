# %%
import pandas as pd

# %%
btsdf = pd.read_csv("BTStracks.csv")
blackpinkdf = pd.read_csv("blackpinktracks.csv")
twicedf = pd.read_csv("twicetracks.csv")
seventeendf = pd.read_csv("seventeentracks.csv")
straykidsdf = pd.read_csv("straykidstracks.csv")
tmrwxtgtdf = pd.read_csv("tomorrowxtgttracks.csv")
newjeansdf = pd.read_csv("newjeanstracks.csv")
gidledf = pd.read_csv("gidletracks.csv")
itzydf = pd.read_csv("itzytracks.csv")
redvelvetdf = pd.read_csv("redvelvettracks.csv")
enhyphendf = pd.read_csv("enhyphentracks.csv")

# %%
btsdf.head()
# Out:
#    Unnamed: 0    tracks.name               tracks.id tracks.artist  \
# 0           1    Born Singer  1IthE5GNiRzFN5CVaCa445           BTS
# 1           2  No More Dream  27S8iOXD7Z58yvJtyk2S9j           BTS
# 2           3            N.O  2GEnvQgSJhedm2sqZlOP8o           BTS
# 3           4     Boy In Luv  0vMk4IrUfSJQkhwZnVX6us           BTS
# 4           5         Danger  0Q53fuiKLGjDKD7Mme7EoQ           BTS
#
#    tracks.disc_number  tracks.track_number  tracks.duration_ms  \
# 0                   1                    1              238628
# 1                   1                    2              222066
# 2                   1                    3              209751
# 3                   1                    4              231384
# 4                   1                    5              245810
#
#    tracks.explicit tracks.album  tracks.key  ...  tracks.time_signature  \
# 0              NaN        Proof           8  ...                      4
# ...

# %%
vertical_stack = pd.concat([btsdf, blackpinkdf, twicedf, seventeendf, straykidsdf, tmrwxtgtdf, newjeansdf, gidledf, itzydf, redvelvetdf, enhyphendf], axis=0)
vertical_stack
# Out:
#     Unnamed: 0             tracks.name               tracks.id tracks.artist  \
# 0            1             Born Singer  1IthE5GNiRzFN5CVaCa445           BTS
# 1            2           No More Dream  27S8iOXD7Z58yvJtyk2S9j           BTS
# 2            3                     N.O  2GEnvQgSJhedm2sqZlOP8o           BTS
# 3            4              Boy In Luv  0vMk4IrUfSJQkhwZnVX6us           BTS
# 4            5                  Danger  0Q53fuiKLGjDKD7Mme7EoQ           BTS
# ..         ...                     ...                     ...           ...
# 74          75             Given-Taken  69WpV0U7OMNFGyq8I63dcC       ENHYPEN
# 75          76     Let Me In (20 CUBE)  4eOcd47wPU3ixxYw0spREl       ENHYPEN
# 76          77               10 Months  3LcFQsZw01tRvjCNLgSmTv       ENHYPEN
# 77          78                 Flicker  3TgPwLFXV6GEIsDZANHktY       ENHYPEN
# 78          79  Outro : Cross the Line  3jkDtDzZKCmWtDccH7UUsq       ENHYPEN
#
# ...

# %%
horizontal_stack = pd.concat([btsdf, blackpinkdf], axis=1)
horizontal_stack
# Out:
#      Unnamed: 0                               tracks.name  \
# 0             1                               Born Singer
# 1             2                             No More Dream
# 2             3                                       N.O
# 3             4                                Boy In Luv
# 4             5                                    Danger
# ..          ...                                       ...
# 269         270                         Wishing On A Star
# 270         271                 Butterfly - Japanese Ver.
# 271         272                                   For You
# 272         273                  I Need U - Japanese Ver.
# 273         274  Epilogue : Young Forever - Japanese Ver.
#
#                   tracks.id tracks.artist  tracks.disc_number  \
# 0    1IthE5GNiRzFN5CVaCa445           BTS                   1
# 1    27S8iOXD7Z58yvJtyk2S9j           BTS                   1
# 2    2GEnvQgSJhedm2sqZlOP8o           BTS                   1
# ...

# %%
vertical_stack.to_csv('allgrouptracks.csv', index=False)

# %%
btsdf['tracks.duration_ms'].mean()
# Out:
# 223222.93795620438

# %%
#could also make a visualization on the time signatures for each group (seems like most are 4/4, easy to bop your head to)

# %%
btsdf['tracks.energy'].mean()
# Out:
# 0.7560072992700723

# %%
btsdf['tracks.tempo'].mean()
# Out:
# 121.57624452554735

# %%
btsdf['tracks.danceability'].mean()
# Out:
# 0.6115291970802923

# %%
btsdf['tracks.liveliness'].mean()
# Out:
# 0.1781302919708029

# %%
blackpinkdf['tracks.duration_ms'].mean()
# Out:
# 203498.8272251309

# %%
blackpinkdf['tracks.energy'].mean()
# Out:
# 0.7057643979057597

# %%
blackpinkdf['tracks.tempo'].mean()
# Out:
# 123.37429319371735

# %%
blackpinkdf['tracks.danceability'].mean()
# Out:
# 0.662151832460733

# %%
blackpinkdf['tracks.liveliness'].mean()
# Out:
# 0.2810774869109947

# %%
df = pd.read_csv("allgrouptracks.csv")
df
# Out:
#       Unnamed: 0             tracks.name               tracks.id  \
# 0              1             Born Singer  1IthE5GNiRzFN5CVaCa445
# 1              2           No More Dream  27S8iOXD7Z58yvJtyk2S9j
# 2              3                     N.O  2GEnvQgSJhedm2sqZlOP8o
# 3              4              Boy In Luv  0vMk4IrUfSJQkhwZnVX6us
# 4              5                  Danger  0Q53fuiKLGjDKD7Mme7EoQ
# ...          ...                     ...                     ...
# 1537          75             Given-Taken  69WpV0U7OMNFGyq8I63dcC
# 1538          76     Let Me In (20 CUBE)  4eOcd47wPU3ixxYw0spREl
# 1539          77               10 Months  3LcFQsZw01tRvjCNLgSmTv
# 1540          78                 Flicker  3TgPwLFXV6GEIsDZANHktY
# 1541          79  Outro : Cross the Line  3jkDtDzZKCmWtDccH7UUsq
#
#      tracks.artist  tracks.disc_number  tracks.track_number  \
# 0              BTS                   1                    1
# 1              BTS                   1                    2
# ...

# %%
df["tracks.time_signature"].unique()
# Out:
# array([4, 3, 5, 1])

# %%
df['count'] = 1
df.head()
# Out:
#    Unnamed: 0    tracks.name               tracks.id tracks.artist  \
# 0           1    Born Singer  1IthE5GNiRzFN5CVaCa445           BTS
# 1           2  No More Dream  27S8iOXD7Z58yvJtyk2S9j           BTS
# 2           3            N.O  2GEnvQgSJhedm2sqZlOP8o           BTS
# 3           4     Boy In Luv  0vMk4IrUfSJQkhwZnVX6us           BTS
# 4           5         Danger  0Q53fuiKLGjDKD7Mme7EoQ           BTS
#
#    tracks.disc_number  tracks.track_number  tracks.duration_ms  \
# 0                   1                    1              238628
# 1                   1                    2              222066
# 2                   1                    3              209751
# 3                   1                    4              231384
# 4                   1                    5              245810
#
#    tracks.explicit tracks.album  tracks.key  ...  tracks.acousticness  \
# 0              NaN        Proof           8  ...             0.035400
# ...

# %%
df.groupby('tracks.time_signature').sum()
# Out:
#                        Unnamed: 0  tracks.disc_number  tracks.track_number  \
# tracks.time_signature
# 1                             301                   4                   39
# 3                            4704                  48                  256
# 4                          141103                1513                 8952
# 5                             358                   6                   15
#
#                        tracks.duration_ms  tracks.explicit  tracks.key  \
# tracks.time_signature
# 1                                  838959              0.0          26
# 3                                 9110977              0.0         170
# 4                               300628092              0.0        8062
# 5                                 1186551              0.0          36
#
#                        tracks.mode  tracks.acousticness  tracks.danceability  \
# tracks.time_signature
# 1                                3             1.539800                1.688
# ...

# %%
#Tallys:
#1 beat per bar: 4
#3 beats per bar: 47
#4 beats per bar: 1485
#5 beats per bar: 6

# %%
import matplotlib.pyplot as plt
import numpy as np
slices = np.array([4, 47, 1485, 6])
mylabels = ["1 beat per bar (.259%)", "3 beats per bar (3.05%)", "4 beats per bar (96.3%)", "5 beats per bar (.389%)"]

# plt.pie(slices)
# plt.legend(labels = mylabels)
# plt.show() 


colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(slices, colors=colors, startangle=90)
plt.legend(patches, mylabels, title = 'Time signature', loc="best")
plt.axis('equal')
plt.title("Time Signatures of top Kpop Songs")
plt.tight_layout()
plt.show()

# %%
pip install pywaffle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 2.5 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle

data ={'timesig': ['1 beat per bar (.259%)', '3 beats per bar (3.05%)', '4 beats per bar (96.3%)', '5 beats per bar (.389%)'],
       'value': [4, 47, 1485, 6]
     }
  
df = pd.DataFrame(data)
  
# To plot the waffle Chart
fig = plt.figure(
    FigureClass = Waffle,
    rows = 10,
    values = df.value,
    labels = list(df.timesig)
)
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
regDf = pd.read_csv("spotifystats.csv")
regDf.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
regDf["genre"].unique()
# Out:
# array(['Movie', 'R&B', 'A Capella', 'Alternative', 'Country', 'Dance',
#        'Electronic', 'Anime', 'Folk', 'Blues', 'Opera', 'Hip-Hop',
#        "Children's Music", 'Children’s Music', 'Rap', 'Indie',
#        'Classical', 'Pop', 'Reggae', 'Reggaeton', 'Jazz', 'Rock', 'Ska',
#        'Comedy', 'Soul', 'Soundtrack', 'World'], dtype=object)

# %%
regDf = regDf[regDf.genre != ('Movie')]
regDf = regDf[regDf.popularity > 40]
regDf = regDf[regDf.time_signature != '0/4']
regDf
# Out:
#        genre     artist_name  \
# 135      R&B   Mary J. Blige
# 136      R&B         Rihanna
# 137      R&B       Yung Bleu
# 138      R&B        Surfaces
# 139      R&B  Olivia O'Brien
# ...      ...             ...
# 232715  Soul      Emily King
# 232717  Soul           Belly
# 232718  Soul    Muddy Waters
# 232722  Soul    Muddy Waters
# 232723  Soul         R.LUM.R
#
#                                                track_name  \
# 135                            Be Without You - Kendu Mix
# 136                                             Desperado
# 137            Ice On My Baby (feat. Kevin Gates) - Remix
# 138                             Heaven Falls / Fall on Me
# 139                                           Love Myself
# ...                                                   ...
# 232715                                               Down
# 232717                                             P.O.P.
# 232718  I Just Want To Make Love To You - Electric Mud...
# ...

# %%
regDf['time_signature'].unique()
# Out:
# array(['4/4', '3/4', '5/4', '1/4'], dtype=object)

# %%
regDf['count'] = 1
regDf.head()
# Out:
#     genre     artist_name                                  track_name  \
# 135   R&B   Mary J. Blige                  Be Without You - Kendu Mix
# 136   R&B         Rihanna                                   Desperado
# 137   R&B       Yung Bleu  Ice On My Baby (feat. Kevin Gates) - Remix
# 138   R&B        Surfaces                   Heaven Falls / Fall on Me
# 139   R&B  Olivia O'Brien                                 Love Myself
#
#                    track_id  popularity  acousticness  danceability  \
# 135  2YegxR5As7BeQuVp2U6pek          65        0.0830         0.724
# 136  6KFaHC9G178beAp7P0Vi5S          63        0.3230         0.685
# 137  6muW8cSjJ3rusKJ0vH5olw          62        0.0675         0.762
# 138  7yHqOZfsXYlicyoMt62yC6          61        0.3600         0.563
# 139  4XzgjxGKqULifVf7mnDIQK          68        0.5960         0.653
#
#      duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# ...

# %%
regDf.groupby('time_signature').sum()
# Out:
#                 popularity  acousticness  danceability  duration_ms  \
# time_signature
# 1/4                  32160    323.368680      272.3484    138963712
# 3/4                 406854   3825.141141     3516.0111   1883330575
# 4/4                6423249  28743.989834    71240.7600  27218094830
# 5/4                  93977    728.094131      832.2021    387963660
#
#                       energy  instrumentalness     liveness    loudness  \
# time_signature
# 1/4               272.632680        136.927059    121.19640   -7474.606
# 3/4              3453.380978       1336.656864   1405.85600  -83699.396
# 4/4             74096.777124       8464.569755  21918.73974 -883740.607
# 5/4               883.473543        220.741298    328.58630  -17154.011
#
#                 speechiness         tempo     valence   count
# time_signature
# 1/4                 79.3402  6.471823e+04    202.2280     620
# 3/4                618.1763  9.736874e+05   2541.4970    7775
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
slices = np.array([620, 7775, 117059, 1735])
mylabels = ["1 beat per bar (0.487%)", "3 beats per bar (6.1%)", "4 beats per bar (92.0%)", "5 beats per bar (1.36%)"]

# plt.pie(slices)
# plt.legend(labels = mylabels)
# plt.show() 


colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(slices, colors=colors, startangle=90)
plt.legend(patches, mylabels, title = 'Time signature', loc="best")
plt.axis('equal')
plt.title("Time Signatures of top Songs")
plt.tight_layout()
plt.show()
